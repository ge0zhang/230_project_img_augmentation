# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.layers import GaussianNoise
import os
import tensorflow.keras.backend as K
from matplotlib.pyplot import imshow
from sklearn.utils import shuffle
np.seterr(divide='ignore', invalid='ignore')
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Activation, BatchNormalization, Flatten, Conv1D,GRU, LSTM, UpSampling1D,GlobalMaxPooling1D, SeparableConv1D,BatchNormalization,UpSampling1D, Conv2D
from tensorflow.keras.layers import AveragePooling1D, MaxPooling1D, Dropout, LeakyReLU, Add, Activation, Concatenate, Permute, Attention, Activation, add
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
from tensorflow.keras.layers import Layer, SimpleRNN, Embedding, GRU, Bidirectional, UpSampling2D,Reshape,Convolution2D, InputLayer
from tensorflow.keras import layers
from tensorflow.keras.layers import SeparableConv2D, MaxPooling2D, Conv2DTranspose
import math
import tensorflow.keras.layers
import tensorflow.keras as keras
import warnings
# import tensorflow_gan as tfgan
# from tqdm import tqdm
# from diffaug import DiffAugment

# %% [markdown]
# ## Data processing

# %%
train_x = np.zeros((200,256,256,3))
t = 0
for i in range(100):
    img = cv2.imread("Aug_output/input16_"+str(1+i)+".tif")
    train_x[t] = img
    t += 1
#     img = cv2.imread("Aug_output/input6_"+str(1+i)+".tif")
#     train_x[t] = img
#     t += 1
    img = cv2.imread("Aug_output/input3_"+str(1+i)+".tif")
    train_x[t] = img
    t += 1

# %%
np.save("train_x",train_x)

# %%
img = cv2.imread("Aug_output/input16_"+str(1)+".tif")

# %%
train_y = np.zeros((200,256,256,3))
t = 0
for i in range(100):
    img = cv2.imread("Aug_output/label16_"+str(1+i)+".tif")
    train_y[t] = img
    t += 1
#     img = cv2.imread("Aug_output/input6_"+str(1+i)+".tif")
#     train_x[t] = img
#     t += 1
    img = cv2.imread("Aug_output/label3_"+str(1+i)+".tif")
    train_y[t] = img
    t += 1

# %%
np.save("train_y",train_y)

# %%
train_x = np.load("train_x.npy")
train_y = np.load("train_y.npy")

# %%
train_x = train_x[:,:,:,0]
train_y = train_y[:,:,:,0]

# %%
train_x = train_x.reshape(train_x.shape[0], train_x.shape[1], train_x.shape[2],1)
train_y = train_y.reshape(train_y.shape[0], train_y.shape[1], train_y.shape[2],1)

# %%
train_y = train_y/255

# %%
## set to be 0/1
plt.imshow(train_y[15,:,:,0])
plt.colorbar()

# %%
## Split data
train_x,train_y=shuffle(train_x,train_y)
num=int(train_x.shape[0]*0.8)
val_x=train_x[num:]
train_x=train_x[0:num]
val_y=train_y[num:]
train_y=train_y[0:num]

# %%
## Define U-net model
# n_timesteps, n_features, n_outputs = train_x.shape[1], train_x.shape[2], train_y.shape[0]-1
input_layer = Input(shape=(train_x.shape[1], train_x.shape[2], train_x.shape[3]))
# Entry block
x = Conv2D(8, 3, strides=2, padding="same")(input_layer)
x = BatchNormalization()(x)
x = Activation("relu")(x)
previous_block_activation = x  

for filters in [16, 32, 64]:
    x = Activation("relu")(x)
    x = SeparableConv2D(filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = SeparableConv2D(filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D(3, strides=2, padding="same")(x)
    residual = layers.Conv2D(filters, 1, strides=2, padding="same")(previous_block_activation)
    x = add([x, residual])  
    previous_block_activation = x  


for filters in [64, 32, 16, 8]:
    x = Activation("relu")(x)
    x = Conv2DTranspose(filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = Conv2DTranspose(filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = UpSampling2D(2)(x)
    residual = UpSampling2D(2)(previous_block_activation)
    residual = Conv2D(filters, 1, padding="same")(residual)
    x = add([x, residual])  
    previous_block_activation = x 
outputs = Conv2D(1,3, padding = "same", activation="linear")(x)
model = Model(input_layer,outputs)
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 256, 256, 1) 0
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 128, 128, 8)  80          input_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 128, 128, 8)  32          conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 128, 128, 8)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 128, 128, 8)  0           activation_45[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_18 (SeparableC (None, 128, 128, 16) 216         activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 128, 128, 16) 64          separable_conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 128, 128, 16) 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_19 (SeparableC (None, 128, 128, 16) 416         activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 128, 128, 16) 64          separable_conv2d_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 64, 64, 16)   0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 64, 64, 16)   144         activation_45[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 64, 64, 16)   0           max_pooling2d_9[0][0]
#                                                                  conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 64, 64, 16)   0           add_21[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_20 (SeparableC (None, 64, 64, 32)   688         activation_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 64, 64, 32)   128         separable_conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 64, 64, 32)   0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_21 (SeparableC (None, 64, 64, 32)   1344        activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 64, 64, 32)   128         separable_conv2d_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 32, 32, 32)   0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 32, 32, 32)   544         add_21[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 32, 32, 32)   0           max_pooling2d_10[0][0]
#                                                                  conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 32, 32, 32)   0           add_22[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_22 (SeparableC (None, 32, 32, 64)   2400        activation_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 32, 32, 64)   256         separable_conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 32, 32, 64)   0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_23 (SeparableC (None, 32, 32, 64)   4736        activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 32, 32, 64)   256         separable_conv2d_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 16, 16, 64)   0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 16, 16, 64)   2112        add_22[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 16, 16, 64)   0           max_pooling2d_11[0][0]
#                                                                  conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 16, 16, 64)   0           add_23[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_24 (Conv2DTran (None, 16, 16, 64)   36928       activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 16, 16, 64)   256         conv2d_transpose_24[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 16, 16, 64)   0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_25 (Conv2DTran (None, 16, 16, 64)   36928       activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 16, 16, 64)   256         conv2d_transpose_25[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_25 (UpSampling2D) (None, 32, 32, 64)   0           add_23[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_24 (UpSampling2D) (None, 32, 32, 64)   0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 32, 32, 64)   4160        up_sampling2d_25[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 32, 32, 64)   0           up_sampling2d_24[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 32, 32, 64)   0           add_24[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_26 (Conv2DTran (None, 32, 32, 32)   18464       activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 32, 32, 32)   128         conv2d_transpose_26[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 32, 32, 32)   0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_27 (Conv2DTran (None, 32, 32, 32)   9248        activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 32, 32, 32)   128         conv2d_transpose_27[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_27 (UpSampling2D) (None, 64, 64, 64)   0           add_24[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_26 (UpSampling2D) (None, 64, 64, 32)   0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 64, 64, 32)   2080        up_sampling2d_27[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 64, 64, 32)   0           up_sampling2d_26[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 64, 64, 32)   0           add_25[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_28 (Conv2DTran (None, 64, 64, 16)   4624        activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 64, 64, 16)   64          conv2d_transpose_28[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 64, 64, 16)   0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_29 (Conv2DTran (None, 64, 64, 16)   2320        activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 64, 64, 16)   64          conv2d_transpose_29[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_29 (UpSampling2D) (None, 128, 128, 32) 0           add_25[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_28 (UpSampling2D) (None, 128, 128, 16) 0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 128, 128, 16) 528         up_sampling2d_29[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 128, 128, 16) 0           up_sampling2d_28[0][0]
#                                                                  conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 128, 128, 16) 0           add_26[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_30 (Conv2DTran (None, 128, 128, 8)  1160        activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 128, 128, 8)  32          conv2d_transpose_30[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 128, 128, 8)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_31 (Conv2DTran (None, 128, 128, 8)  584         activation_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 128, 128, 8)  32          conv2d_transpose_31[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_31 (UpSampling2D) (None, 256, 256, 16) 0           add_26[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_30 (UpSampling2D) (None, 256, 256, 8)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 256, 256, 8)  136         up_sampling2d_31[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 256, 256, 8)  0           up_sampling2d_30[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 256, 256, 1)  73          add_27[0][0]
# ==================================================================================================
# Total params: 131,801
# Trainable params: 130,857
# Non-trainable params: 944
# __________________________________________________________________________________________________

# %%
## self define a loss function
def soft_dice_loss(y_true, y_pred): 
    epsilon=1e-6
    axes = tuple(range(1, len(y_pred.shape)-1)) 
    numerator = 2. * K.sum(y_pred * y_true, axes)
    denominator = K.sum(np.square(y_pred) + np.square(y_true),axes)
    
    return 1 - K.mean((numerator + epsilon) / (denominator + epsilon)) # average over classes and batch

# %%
## try pixel-wise cross-entropy
"""
    Pixel-wise cross-entropy loss for dense classification of an image.
       
    The loss of a misclassified `1` needs to be weighted
    `WEIGHT` times more than a misclassified `0` (only 2 classes).
   
    Inputs
    ----------------
    y_true: Correct labels of 3D shape (batch_size, img_rows*img_cols, num_classes).
   
    y_pred: Predicted softmax probabilities of each class for each img_rows*img_cols pixel.
            Same 3D shape as y_true.
    """
def pixelwise_crossentropy(y_true, y_pred):
    y_true = tf.reshape(y_true, [10,256*256])
    y_pred = tf.reshape(y_pred, [10,256*256])
    loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=y_true, logits=y_pred)
    return K.sum(loss)

# %% [markdown]
# ## Try different loss function

# %% [markdown]
# #### 1. Soft dice loss

# %%
## Try soft dice loss
model.compile("adam",soft_dice_loss)
history1=model.fit(train_x, train_y, validation_data=(val_x,val_y), epochs=40, batch_size=10, shuffle=True)
# Out:
# Train on 160 samples, validate on 40 samples
# Epoch 1/40
# 160/160 [==============================] - 39s 244ms/sample - loss: 0.8896 - val_loss: 1.0292
# Epoch 2/40
# 160/160 [==============================] - 37s 229ms/sample - loss: 0.7172 - val_loss: 1.0314
# Epoch 3/40
# 160/160 [==============================] - 34s 213ms/sample - loss: 0.6050 - val_loss: 1.0446
# Epoch 4/40
# 160/160 [==============================] - 38s 240ms/sample - loss: 0.5986 - val_loss: 1.0896
# Epoch 5/40
# 160/160 [==============================] - 37s 228ms/sample - loss: 0.4940 - val_loss: 1.0197
# Epoch 6/40
# 160/160 [==============================] - 31s 193ms/sample - loss: 0.4142 - val_loss: 0.7289
# Epoch 7/40
# 160/160 [==============================] - 31s 191ms/sample - loss: 0.3808 - val_loss: 0.6475
# Epoch 8/40
# 160/160 [==============================] - 30s 190ms/sample - loss: 0.3776 - val_loss: 0.6016
# Epoch 9/40
# 160/160 [==============================] - 31s 192ms/sample - loss: 0.2402 - val_loss: 0.2732
# Epoch 38/40
# 160/160 [==============================] - 31s 191ms/sample - loss: 0.2386 - val_loss: 0.2727
# Epoch 39/40
# 160/160 [==============================] - 31s 193ms/sample - loss: 0.2359 - val_loss: 0.2647
# Epoch 40/40
# 160/160 [==============================] - 31s 192ms/sample - loss: 0.2320 - val_loss: 0.2799

# %%
plt.plot(history1.history['loss'])

# %%
plt.imshow(val_y[15,:,:,0])
plt.colorbar()

# %%
valPred = model.predict(val_x)
plt.imshow(valPred[15,:,:,0])
plt.colorbar()

# %% [markdown]
# #### 2. Mean squared error

# %%
## Try soft dice loss
model.compile("adam","mse")
history1=model.fit(train_x, train_y, validation_data=(val_x,val_y), epochs=200, batch_size=10, shuffle=True)

# %%
plt.plot(history1.history['loss'])

# %%
plt.imshow(train_y[15,:,:,0])

# %%
trainPred = model.predict(train_x)

# %%
plt.imshow(trainPred[15,:,:,0])

# %%
valPred = model.predict(val_x)

# %%
plt.imshow(val_y[15,:,:,0])

# %%
## plot >10
plt.imshow(valPred[15,:,:,0]>10)
plt.colorbar()

# %% [markdown]
# #### 3. sparse categorical crossentropy

# %%
# scc = tf.keras.losses.SparseCategoricalCrossentropy(reduction=tf.compat.v1.losses.Reduction.NONE)
model.compile("adam", loss=pixelwise_crossentropy)
history1=model.fit(train_x, train_y, validation_data=(val_x,val_y), epochs=200, batch_size=10, shuffle=True)
# Out:
# Train on 160 samples, validate on 40 samples
# Epoch 1/200
# 160/160 [==============================] - 39s 242ms/sample - loss: 222078.0146 - val_loss: 188294.6523
# Epoch 2/200
# 160/160 [==============================] - 31s 197ms/sample - loss: 148084.6211 - val_loss: 164535.8438
# Epoch 3/200
# 160/160 [==============================] - 31s 196ms/sample - loss: 138701.8672 - val_loss: 148196.0977
# Epoch 4/200
# 160/160 [==============================] - 31s 197ms/sample - loss: 135313.6328 - val_loss: 142901.3164
# Epoch 5/200
# 160/160 [==============================] - 31s 197ms/sample - loss: 130600.9429 - val_loss: 140474.2500
# Epoch 6/200
# 160/160 [==============================] - 31s 197ms/sample - loss: 128977.9595 - val_loss: 136822.4258
# Epoch 7/200
# 160/160 [==============================] - 32s 197ms/sample - loss: 127188.5337 - val_loss: 130458.6113
# Epoch 8/200
# 160/160 [==============================] - 31s 197ms/sample - loss: 124968.0820 - val_loss: 131135.6543
# Epoch 9/200
# 160/160 [==============================] - 31s 196ms/sample - loss: 124212.8330 - val_loss: 126241.8945
# Epoch 10/200
# 160/160 [==============================] - 31s 195ms/sample - loss: 121935.9326 - val_loss: 126047.8105
# Epoch 11/200
# 160/160 [==============================] - 31s 195ms/sample - loss: 122402.7905 - val_loss: 122920.3184
# Epoch 12/200
# 160/160 [==============================] - 32s 197ms/sample - loss: 119721.6826 - val_loss: 123620.8203
# Epoch 13/200
# 160/160 [==============================] - 32s 197ms/sample - loss: 118441.7129 - val_loss: 121522.7695
# Epoch 14/200
# 160/160 [==============================] - 32s 197ms/sample - loss: 117450.1284 - val_loss: 122812.6426
