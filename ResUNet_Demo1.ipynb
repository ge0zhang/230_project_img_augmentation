# %% [markdown]
# # Porous media segmentation based on image augmentation

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import math
import warnings

from matplotlib.pyplot import imshow
from sklearn.utils import shuffle

import tensorflow as tf
import tensorflow.keras.backend as K
import tensorflow.keras.layers
import tensorflow.keras as keras

from tensorflow.keras.layers import Input, BatchNormalization, Conv2D
from tensorflow.keras.layers import Dropout, Add, Activation, Concatenate, Permute
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
from tensorflow.keras import layers

# %% [markdown]
# ## Data processing

# %% [markdown]
# ### Training & Devlopment set

# %%
train_x = np.load("train_x.npy")
train_y = np.load("train_y.npy")

val_x = np.load("val_x.npy")
val_y = np.load("val_y.npy")

test_x = np.load("test_x.npy")
test_y = np.load("test_y.npy")

# %% [markdown]
# ## ResU-net model

# %%
def Stem(x, filters): 
    sc = x
    x = layers.Conv2D(filters, (3,3), padding="same", strides=1, kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Dropout(0.3)(x)
    x = layers.Conv2D(filters, (3,3), padding="same", strides=1, kernel_initializer="he_normal")(x)
    # Residual
    sc = layers.Conv2D(filters, (1,1), padding="same", strides=1, kernel_initializer="he_normal")(sc)
    sc = layers.BatchNormalization()(sc)
    out = layers.Add()([x, sc])  

    return out

def Res_Block(x, filters, s): 
    sc = x
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Dropout(0.3)(x)
    
    # Down-sampling
    x = layers.Conv2D(filters, (3,3), padding="same", strides=s, kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Dropout(0.3)(x)
    x = layers.Conv2D(filters, (3,3), padding="same", strides=1, kernel_initializer="he_normal")(x)
   
    # Residual
    sc = layers.Conv2D(filters, (1,1), padding="same", strides=s, kernel_initializer="he_normal")(sc)
    sc = layers.BatchNormalization()(sc)
    out = layers.Add()([x, sc])  

    return out

def Up_block(x, skip, filters): 
    x = layers.UpSampling2D((2, 2))(x)
    out = layers.concatenate([x, skip], axis=3)
    
    return out

input_layer = Input(shape=(train_x.shape[1], train_x.shape[2], train_x.shape[3]))
# Entry block
stem = Stem(input_layer, 16) 
x = stem

# Encoder
for idx, filters in enumerate([32, 64, 128, 256]):  
    x = Res_Block(x, filters, 2) 

    if idx == 0:
        # 128 by 128
        conv1 = x
    elif idx == 1:
        # 64 by 64
        conv2 = x
    elif idx == 2:
        # 32 by 32
        conv3 = x
    elif idx == 3:
        # 16 by 16
        conv4 = x

# Bottleneck
x = layers.BatchNormalization()(x)
x = layers.Activation("relu")(x)
x = layers.Dropout(0.3)(x)
x = layers.Conv2D(256, (3,3), padding="same", strides=1, kernel_initializer="he_normal")(x)
x = layers.BatchNormalization()(x)
x = layers.Activation("relu")(x)
x = layers.Dropout(0.3)(x)
x = layers.Conv2D(256, (3,3), padding="same", strides=1, kernel_initializer="he_normal")(x)

# Decoder
for idx, filters in enumerate([256, 128, 64, 32]):
    if idx == 0:
        x = Up_block(x, conv3, filters)    #32 by 32
        x = Res_Block(x, filters, 1) 
    elif idx == 1:
        x = Up_block(x, conv2, filters)    #64 by 64
        x = Res_Block(x, filters, 1) 
    elif idx == 2:
        x = Up_block(x, conv1, filters)    #128 by 128
        x = Res_Block(x, filters, 1) 
    elif idx == 3:
        x = Up_block(x, stem, filters)     #256 by 256
        x = Res_Block(x, filters, 1) 
                
# Channel-wise pooling
out = Conv2D(1, (1,1), activation='sigmoid', padding='same', kernel_initializer="he_normal")(x)

model = Model(input_layer, out)
model.summary()
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_13 (InputLayer)          [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d_360 (Conv2D)            (None, 256, 256, 16  160         ['input_13[0][0]']
#                                 )
#
#  batch_normalization_336 (Batch  (None, 256, 256, 16  64         ['conv2d_360[0][0]']
#  Normalization)                 )
#
#  activation_228 (Activation)    (None, 256, 256, 16  0           ['batch_normalization_336[0][0]']
#                                 )
#
#  dropout_140 (Dropout)          (None, 256, 256, 16  0           ['activation_228[0][0]']
#                                 )
#
#  conv2d_362 (Conv2D)            (None, 256, 256, 16  32          ['input_13[0][0]']
#                                 )
#
#  conv2d_361 (Conv2D)            (None, 256, 256, 16  2320        ['dropout_140[0][0]']
#                                 )
#
#  batch_normalization_337 (Batch  (None, 256, 256, 16  64         ['conv2d_362[0][0]']
#  Normalization)                 )
#
#  add_108 (Add)                  (None, 256, 256, 16  0           ['conv2d_361[0][0]',
#                                 )                                 'batch_normalization_337[0][0]']
#
#  batch_normalization_338 (Batch  (None, 256, 256, 16  64         ['add_108[0][0]']
#  Normalization)                 )
#
#  activation_229 (Activation)    (None, 256, 256, 16  0           ['batch_normalization_338[0][0]']
#                                 )
#
#  dropout_141 (Dropout)          (None, 256, 256, 16  0           ['activation_229[0][0]']
#                                 )
#
#  conv2d_363 (Conv2D)            (None, 128, 128, 32  4640        ['dropout_141[0][0]']
#                                 )
#
#  batch_normalization_339 (Batch  (None, 128, 128, 32  128        ['conv2d_363[0][0]']
#  Normalization)                 )
#
#  activation_230 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_339[0][0]']
#                                 )
#
#  dropout_142 (Dropout)          (None, 128, 128, 32  0           ['activation_230[0][0]']
#                                 )
#
#  conv2d_365 (Conv2D)            (None, 128, 128, 32  544         ['add_108[0][0]']
#                                 )
#
#  conv2d_364 (Conv2D)            (None, 128, 128, 32  9248        ['dropout_142[0][0]']
#                                 )
#
#  batch_normalization_340 (Batch  (None, 128, 128, 32  128        ['conv2d_365[0][0]']
#  Normalization)                 )
#
#  add_109 (Add)                  (None, 128, 128, 32  0           ['conv2d_364[0][0]',
#                                 )                                 'batch_normalization_340[0][0]']
#
#  batch_normalization_341 (Batch  (None, 128, 128, 32  128        ['add_109[0][0]']
#  Normalization)                 )
#
#  activation_231 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_341[0][0]']
#                                 )
#
#  dropout_143 (Dropout)          (None, 128, 128, 32  0           ['activation_231[0][0]']
#                                 )
#
#  conv2d_366 (Conv2D)            (None, 64, 64, 64)   18496       ['dropout_143[0][0]']
#
#  batch_normalization_342 (Batch  (None, 64, 64, 64)  256         ['conv2d_366[0][0]']
#  Normalization)
#
#  activation_232 (Activation)    (None, 64, 64, 64)   0           ['batch_normalization_342[0][0]']
#
#  dropout_144 (Dropout)          (None, 64, 64, 64)   0           ['activation_232[0][0]']
#
#  conv2d_368 (Conv2D)            (None, 64, 64, 64)   2112        ['add_109[0][0]']
#
#  conv2d_367 (Conv2D)            (None, 64, 64, 64)   36928       ['dropout_144[0][0]']
#
#  batch_normalization_343 (Batch  (None, 64, 64, 64)  256         ['conv2d_368[0][0]']
#  Normalization)
#
#  add_110 (Add)                  (None, 64, 64, 64)   0           ['conv2d_367[0][0]',
#                                                                   'batch_normalization_343[0][0]']
#
#  batch_normalization_344 (Batch  (None, 64, 64, 64)  256         ['add_110[0][0]']
#  Normalization)
#
#  activation_233 (Activation)    (None, 64, 64, 64)   0           ['batch_normalization_344[0][0]']
#
#  dropout_145 (Dropout)          (None, 64, 64, 64)   0           ['activation_233[0][0]']
#
#  conv2d_369 (Conv2D)            (None, 32, 32, 128)  73856       ['dropout_145[0][0]']
#
#  batch_normalization_345 (Batch  (None, 32, 32, 128)  512        ['conv2d_369[0][0]']
#  Normalization)
#
#  activation_234 (Activation)    (None, 32, 32, 128)  0           ['batch_normalization_345[0][0]']
#
#  dropout_146 (Dropout)          (None, 32, 32, 128)  0           ['activation_234[0][0]']
#
#  conv2d_371 (Conv2D)            (None, 32, 32, 128)  8320        ['add_110[0][0]']
#
#  conv2d_370 (Conv2D)            (None, 32, 32, 128)  147584      ['dropout_146[0][0]']
#
#  batch_normalization_346 (Batch  (None, 32, 32, 128)  512        ['conv2d_371[0][0]']
#  Normalization)
#
#  add_111 (Add)                  (None, 32, 32, 128)  0           ['conv2d_370[0][0]',
#                                                                   'batch_normalization_346[0][0]']
#
#  batch_normalization_347 (Batch  (None, 32, 32, 128)  512        ['add_111[0][0]']
#  Normalization)
#
#  activation_235 (Activation)    (None, 32, 32, 128)  0           ['batch_normalization_347[0][0]']
#
#  dropout_147 (Dropout)          (None, 32, 32, 128)  0           ['activation_235[0][0]']
#
#  conv2d_372 (Conv2D)            (None, 16, 16, 256)  295168      ['dropout_147[0][0]']
#
#  batch_normalization_348 (Batch  (None, 16, 16, 256)  1024       ['conv2d_372[0][0]']
#  Normalization)
#
#  activation_236 (Activation)    (None, 16, 16, 256)  0           ['batch_normalization_348[0][0]']
#
#  dropout_148 (Dropout)          (None, 16, 16, 256)  0           ['activation_236[0][0]']
#
#  conv2d_374 (Conv2D)            (None, 16, 16, 256)  33024       ['add_111[0][0]']
#
#  conv2d_373 (Conv2D)            (None, 16, 16, 256)  590080      ['dropout_148[0][0]']
#
#  batch_normalization_349 (Batch  (None, 16, 16, 256)  1024       ['conv2d_374[0][0]']
#  Normalization)
#
#  add_112 (Add)                  (None, 16, 16, 256)  0           ['conv2d_373[0][0]',
#                                                                   'batch_normalization_349[0][0]']
#
#  batch_normalization_350 (Batch  (None, 16, 16, 256)  1024       ['add_112[0][0]']
#  Normalization)
#
#  activation_237 (Activation)    (None, 16, 16, 256)  0           ['batch_normalization_350[0][0]']
#
#  dropout_149 (Dropout)          (None, 16, 16, 256)  0           ['activation_237[0][0]']
#
#  conv2d_375 (Conv2D)            (None, 16, 16, 256)  590080      ['dropout_149[0][0]']
#
#  batch_normalization_351 (Batch  (None, 16, 16, 256)  1024       ['conv2d_375[0][0]']
#  Normalization)
#
#  activation_238 (Activation)    (None, 16, 16, 256)  0           ['batch_normalization_351[0][0]']
#
#  dropout_150 (Dropout)          (None, 16, 16, 256)  0           ['activation_238[0][0]']
#
#  conv2d_376 (Conv2D)            (None, 16, 16, 256)  590080      ['dropout_150[0][0]']
#
#  up_sampling2d_48 (UpSampling2D  (None, 32, 32, 256)  0          ['conv2d_376[0][0]']
#  )
#
#  concatenate_48 (Concatenate)   (None, 32, 32, 384)  0           ['up_sampling2d_48[0][0]',
#                                                                   'add_111[0][0]']
#
#  batch_normalization_352 (Batch  (None, 32, 32, 384)  1536       ['concatenate_48[0][0]']
#  Normalization)
#
#  activation_239 (Activation)    (None, 32, 32, 384)  0           ['batch_normalization_352[0][0]']
#
#  dropout_151 (Dropout)          (None, 32, 32, 384)  0           ['activation_239[0][0]']
#
#  conv2d_377 (Conv2D)            (None, 32, 32, 256)  884992      ['dropout_151[0][0]']
#
#  batch_normalization_353 (Batch  (None, 32, 32, 256)  1024       ['conv2d_377[0][0]']
#  Normalization)
#
#  activation_240 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_353[0][0]']
#
#  dropout_152 (Dropout)          (None, 32, 32, 256)  0           ['activation_240[0][0]']
#
#  conv2d_379 (Conv2D)            (None, 32, 32, 256)  98560       ['concatenate_48[0][0]']
#
#  conv2d_378 (Conv2D)            (None, 32, 32, 256)  590080      ['dropout_152[0][0]']
#
#  batch_normalization_354 (Batch  (None, 32, 32, 256)  1024       ['conv2d_379[0][0]']
#  Normalization)
#
#  add_113 (Add)                  (None, 32, 32, 256)  0           ['conv2d_378[0][0]',
#                                                                   'batch_normalization_354[0][0]']
#
#  up_sampling2d_49 (UpSampling2D  (None, 64, 64, 256)  0          ['add_113[0][0]']
#  )
#
#  concatenate_49 (Concatenate)   (None, 64, 64, 320)  0           ['up_sampling2d_49[0][0]',
#                                                                   'add_110[0][0]']
#
#  batch_normalization_355 (Batch  (None, 64, 64, 320)  1280       ['concatenate_49[0][0]']
#  Normalization)
#
#  activation_241 (Activation)    (None, 64, 64, 320)  0           ['batch_normalization_355[0][0]']
#
#  dropout_153 (Dropout)          (None, 64, 64, 320)  0           ['activation_241[0][0]']
#
#  conv2d_380 (Conv2D)            (None, 64, 64, 128)  368768      ['dropout_153[0][0]']
#
#  batch_normalization_356 (Batch  (None, 64, 64, 128)  512        ['conv2d_380[0][0]']
#  Normalization)
#
#  activation_242 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_356[0][0]']
#
#  dropout_154 (Dropout)          (None, 64, 64, 128)  0           ['activation_242[0][0]']
#
#  conv2d_382 (Conv2D)            (None, 64, 64, 128)  41088       ['concatenate_49[0][0]']
#
#  conv2d_381 (Conv2D)            (None, 64, 64, 128)  147584      ['dropout_154[0][0]']
#
#  batch_normalization_357 (Batch  (None, 64, 64, 128)  512        ['conv2d_382[0][0]']
#  Normalization)
#
#  add_114 (Add)                  (None, 64, 64, 128)  0           ['conv2d_381[0][0]',
#                                                                   'batch_normalization_357[0][0]']
#
#  up_sampling2d_50 (UpSampling2D  (None, 128, 128, 12  0          ['add_114[0][0]']
#  )                              8)
#
#  concatenate_50 (Concatenate)   (None, 128, 128, 16  0           ['up_sampling2d_50[0][0]',
#                                 0)                                'add_109[0][0]']
#
#  batch_normalization_358 (Batch  (None, 128, 128, 16  640        ['concatenate_50[0][0]']
#  Normalization)                 0)
#
#  activation_243 (Activation)    (None, 128, 128, 16  0           ['batch_normalization_358[0][0]']
#                                 0)
#
#  dropout_155 (Dropout)          (None, 128, 128, 16  0           ['activation_243[0][0]']
#                                 0)
#
#  conv2d_383 (Conv2D)            (None, 128, 128, 64  92224       ['dropout_155[0][0]']
#                                 )
#
#  batch_normalization_359 (Batch  (None, 128, 128, 64  256        ['conv2d_383[0][0]']
#  Normalization)                 )
#
#  activation_244 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_359[0][0]']
#                                 )
#
#  dropout_156 (Dropout)          (None, 128, 128, 64  0           ['activation_244[0][0]']
#                                 )
#
#  conv2d_385 (Conv2D)            (None, 128, 128, 64  10304       ['concatenate_50[0][0]']
#                                 )
#
#  conv2d_384 (Conv2D)            (None, 128, 128, 64  36928       ['dropout_156[0][0]']
#                                 )
#
#  batch_normalization_360 (Batch  (None, 128, 128, 64  256        ['conv2d_385[0][0]']
#  Normalization)                 )
#
#  add_115 (Add)                  (None, 128, 128, 64  0           ['conv2d_384[0][0]',
#                                 )                                 'batch_normalization_360[0][0]']
#
#  up_sampling2d_51 (UpSampling2D  (None, 256, 256, 64  0          ['add_115[0][0]']
#  )                              )
#
#  concatenate_51 (Concatenate)   (None, 256, 256, 80  0           ['up_sampling2d_51[0][0]',
#                                 )                                 'add_108[0][0]']
#
#  batch_normalization_361 (Batch  (None, 256, 256, 80  320        ['concatenate_51[0][0]']
#  Normalization)                 )
#
#  activation_245 (Activation)    (None, 256, 256, 80  0           ['batch_normalization_361[0][0]']
#                                 )
#
#  dropout_157 (Dropout)          (None, 256, 256, 80  0           ['activation_245[0][0]']
#                                 )
#
#  conv2d_386 (Conv2D)            (None, 256, 256, 32  23072       ['dropout_157[0][0]']
#                                 )
#
#  batch_normalization_362 (Batch  (None, 256, 256, 32  128        ['conv2d_386[0][0]']
#  Normalization)                 )
#
#  activation_246 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_362[0][0]']
#                                 )
#
#  dropout_158 (Dropout)          (None, 256, 256, 32  0           ['activation_246[0][0]']
#                                 )
#
#  conv2d_388 (Conv2D)            (None, 256, 256, 32  2592        ['concatenate_51[0][0]']
#                                 )
#
#  conv2d_387 (Conv2D)            (None, 256, 256, 32  9248        ['dropout_158[0][0]']
#                                 )
#
#  batch_normalization_363 (Batch  (None, 256, 256, 32  128        ['conv2d_388[0][0]']
#  Normalization)                 )
#
#  add_116 (Add)                  (None, 256, 256, 32  0           ['conv2d_387[0][0]',
#                                 )                                 'batch_normalization_363[0][0]']
#
#  conv2d_389 (Conv2D)            (None, 256, 256, 1)  33          ['add_116[0][0]']
#
# ==================================================================================================
# Total params: 4,722,737
# Trainable params: 4,715,441
# Non-trainable params: 7,296
# __________________________________________________________________________________________________

# %% [markdown]
# ## Try different loss function

# %% [markdown]
# #### - binary cross entropy
# #### - L1 loss
# #### - sparse categorical crossentropy

# %%
def loss_func(y_true, y_pred):
    loss = K.mean(K.abs(y_pred - y_true), axis=-1) + tf.keras.losses.BinaryCrossentropy(from_logits=True)(y_true, y_pred) 
    
    return loss

# %%
# scc = tf.keras.losses.SparseCategoricalCrossentropy(reduction=tf.compat.v1.losses.Reduction.NONE)
model.compile("adam", loss=loss_func)
history1=model.fit(train_x, train_y, validation_data=(val_x,val_y), epochs=30, batch_size=16, shuffle=True)
# Out:
# Epoch 1/30
# 80/80 [==============================] - 26s 277ms/step - loss: 0.2710 - val_loss: 286.2232
# Epoch 2/30
# 80/80 [==============================] - 21s 257ms/step - loss: 0.1817 - val_loss: 21.4106
# Epoch 3/30
# 80/80 [==============================] - 21s 260ms/step - loss: 0.1287 - val_loss: 0.1721
# Epoch 4/30
# 80/80 [==============================] - 21s 259ms/step - loss: 0.1689 - val_loss: 0.3834
# Epoch 5/30
# 80/80 [==============================] - 21s 260ms/step - loss: 0.1536 - val_loss: 0.1359
# Epoch 6/30
# 80/80 [==============================] - 21s 263ms/step - loss: 0.1261 - val_loss: 0.2229
# Epoch 7/30
# 80/80 [==============================] - 20s 256ms/step - loss: 0.1120 - val_loss: 0.1999
# Epoch 8/30
# 80/80 [==============================] - 21s 259ms/step - loss: 0.1103 - val_loss: 0.2572
# Epoch 9/30
# 80/80 [==============================] - 20s 255ms/step - loss: 0.1031 - val_loss: 0.2573
# Epoch 10/30
# 80/80 [==============================] - 21s 260ms/step - loss: 0.1087 - val_loss: 0.2545
# Epoch 11/30
# 80/80 [==============================] - 21s 261ms/step - loss: 0.0977 - val_loss: 0.2254
# Epoch 12/30
# 80/80 [==============================] - 21s 263ms/step - loss: 0.1151 - val_loss: 0.1525
# Epoch 13/30
# 80/80 [==============================] - 20s 256ms/step - loss: 0.1118 - val_loss: 0.2083
# Epoch 14/30
# 80/80 [==============================] - 21s 260ms/step - loss: 0.0985 - val_loss: 0.2029
# Epoch 15/30
# 80/80 [==============================] - 21s 262ms/step - loss: 0.0997 - val_loss: 0.2045
# Epoch 16/30
# 80/80 [==============================] - 23s 290ms/step - loss: 0.0933 - val_loss: 0.1836
# Epoch 17/30
# 80/80 [==============================] - 22s 269ms/step - loss: 0.0889 - val_loss: 0.2140
# Epoch 18/30
# 80/80 [==============================] - 21s 267ms/step - loss: 0.0887 - val_loss: 0.2169
# Epoch 19/30
# 80/80 [==============================] - 21s 264ms/step - loss: 0.0904 - val_loss: 0.2139
# Epoch 20/30
# 80/80 [==============================] - 21s 264ms/step - loss: 0.0883 - val_loss: 0.2343
# Epoch 21/30
# 80/80 [==============================] - 21s 263ms/step - loss: 0.0902 - val_loss: 0.2028
# Epoch 22/30
# 80/80 [==============================] - 21s 263ms/step - loss: 0.0946 - val_loss: 0.1807
# Epoch 23/30
# 80/80 [==============================] - 20s 256ms/step - loss: 0.0858 - val_loss: 0.1884
# Epoch 24/30
# 80/80 [==============================] - 21s 259ms/step - loss: 0.0913 - val_loss: 0.2511
# Epoch 25/30
# 80/80 [==============================] - 21s 264ms/step - loss: 0.0892 - val_loss: 0.2142
# Epoch 26/30
# 80/80 [==============================] - 21s 258ms/step - loss: 0.0887 - val_loss: 0.2129
# Epoch 27/30
# 80/80 [==============================] - 21s 267ms/step - loss: 0.0869 - val_loss: 0.2147
# Epoch 28/30
# 80/80 [==============================] - 20s 256ms/step - loss: 0.0826 - val_loss: 0.2049
# Epoch 29/30
# 80/80 [==============================] - 20s 255ms/step - loss: 0.0830 - val_loss: 0.2061
# Epoch 30/30
# 80/80 [==============================] - 21s 268ms/step - loss: 0.0828 - val_loss: 0.2098

# %%
plt.figure()
outlier = 46
outlier2 = 99
train_loss = history1.history['loss'][:outlier-1] + history1.history['loss'][outlier:outlier2-1] + history1.history['loss'][outlier2:]
val_loss = history1.history['val_loss'][:outlier-1] + history1.history['val_loss'][outlier:outlier2-1]+ history1.history['val_loss'][outlier2:]
plt.plot(train_loss,label="training loss")
plt.plot(val_loss,label="validation loss")
plt.ylim([0, 3])
plt.legend()
plt.ylabel("Loss")
plt.xlabel("Epoch")
# Out:
# Text(0.5, 0, 'Epoch')

# %%
plt.imshow(test_y[12,:,:,0], cmap='Greys')
plt.colorbar()
plt.show()

# %%
testPred = model.predict(test_x)
# Out:
# 16/16 [==============================] - 2s 120ms/step

# %%
plt.imshow(testPred[12,:,:,0], cmap='Greys')
plt.colorbar()
plt.show()

# %%
plt.imshow(test_y[7,:,:,0], cmap='Greys')
plt.colorbar()
plt.show()

# %%
plt.imshow(testPred[7,:,:,0], cmap='Greys')
plt.colorbar()
plt.show()

# %%
plt.imshow(test_y[15,:,:,0], cmap='Greys')
plt.colorbar()
plt.show()

# %%
plt.imshow(testPred[15,:,:,0], cmap='Greys')
plt.colorbar()
plt.show()

# %%
def iou_coef(true, pred, smooth=1):
  intersection = K.sum(K.abs(true * pred))
  union = K.sum(true)+K.sum(pred)-intersection
  iou = K.mean((intersection + smooth) / (union + smooth))
  return iou

iou_acc = 0

for i in range(len(test_y)):
    test_y = tf.cast(test_y, tf.double)
    testPred = tf.cast(testPred, tf.double)
    iou_acc += iou_coef(test_y[i,:,:,0], testPred[i,:,:,0], smooth=1)
    
iou_acc = iou_acc/(i+1)

print(iou_acc)
# Out:
# tf.Tensor(0.7770366810120096, shape=(), dtype=float64)
